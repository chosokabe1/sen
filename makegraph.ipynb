# %%
import matplotlib.pyplot as plt

file = "train_acc.txt"
with open(file) as fileobj:
  text = fileobj.read()
  print(text)
  list = text.split(",")
  print(list)

data = []
for index,i in enumerate(list):
  print(index)
  i = i.replace("'", "")
  data.append(float(i))

plt.plot(data)
plt.title("train_accuracy-epoch")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.grid(True)
plt.show()
# Out:
# 0.5083333333333333,0.5888888888888889,0.6611111111111111
# ['0.5083333333333333', '0.5888888888888889', '0.6611111111111111']
# 0
# 1
# 2
